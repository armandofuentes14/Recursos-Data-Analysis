# %% [markdown]
# # Ex2 - Filtering and Sorting Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
euro12 = pd.read_csv("Euro_2012_stats_TEAM.csv", header=0, index_col=None, sep=",")

# %%
import pandas as pd

df = pd.DataFrame({"a":list("aeiou"), "b":["ahdgfds,d", "ghdshgds,dgud,d", "s", "c", "e"]})

# %%
df.to_csv("test.csv")

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv). O desde el excel que tienes en la misma carpeta

# %% [markdown]
# ### Step 3. Assign it to a variable called euro12.

# %%
pd.set_option('display.max_columns', None) 
# Por si quieres que te aparezcan todas las columnas del dataset, si no es caso no ejecutes esta celda

# %%
euro12.head()
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 0            16.0%                          32             0              0
# 1            12.9%                          39             0              0
# 2            20.0%                          27             1              0
# 3            17.2%                          40             0              0
# 4             6.5%                          65             1              0
#
# ...

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 35 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Team                        16 non-null     object
#  1   Goals                       16 non-null     int64
#  2   Shots on target             16 non-null     int64
#  3   Shots off target            16 non-null     int64
#  4   Shooting Accuracy           16 non-null     object
#  5   % Goals-to-shots            16 non-null     object
#  6   Total shots (inc. Blocked)  16 non-null     int64
#  7   Hit Woodwork                16 non-null     int64
#  8   Penalty goals               16 non-null     int64
#  9   Penalties not scored        16 non-null     int64
#  10  Headed goals                16 non-null     int64
#  11  Passes                      16 non-null     int64
#  12  Passes completed            16 non-null     int64
# ...

# %% [markdown]
# ### Step 4. Select only the Goal column.

# %%
pd.DataFrame(euro12["Goals"])
# Out:
#     Goals
# 0       4
# 1       4
# 2       4
# 3       5
# 4       3
# 5      10
# 6       5
# 7       6
# 8       2
# 9       2
# 10      6
# 11      1
# 12      5
# 13     12
# 14      5
# 15      2

# %%
euro12.iloc[:, 1:2]
# Out:
#     Goals
# 0       4
# 1       4
# 2       4
# 3       5
# 4       3
# 5      10
# 6       5
# 7       6
# 8       2
# 9       2
# 10      6
# 11      1
# 12      5
# 13     12
# 14      5
# 15      2

# %%
euro12[["Goals"]]
# Out:
#     Goals
# 0       4
# 1       4
# 2       4
# 3       5
# 4       3
# 5      10
# 6       5
# 7       6
# 8       2
# 9       2
# 10      6
# 11      1
# 12      5
# 13     12
# 14      5
# 15      2

# %% [markdown]
# ### Step 5. How many team participated in the Euro2012?

# %%
euro12.Team.unique()
# Out:
# Croatia                1
# Czech Republic         1
# Denmark                1
# England                1
# France                 1
# Germany                1
# Greece                 1
# Italy                  1
# Netherlands            1
# Poland                 1
# Portugal               1
# Republic of Ireland    1
# Russia                 1
# Spain                  1
# Sweden                 1
# Ukraine                1
# Name: Team, dtype: int64

# %% [markdown]
# ### Step 6. What is the number of columns in the dataset?

# %%
len(euro12.columns)
# Out:
# 35

# %% [markdown]
# ### Step 7. View only the columns Team, Yellow Cards and Red Cards and assign them to a dataframe called discipline

# %%
discipline = euro12.loc[:, ["Team", "Yellow Cards", "Red Cards"]].copy()
discipline
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %% [markdown]
# ### Step 8. Sort the teams by Red Cards, then to Yellow Cards

# %%
discipline.sort_values(["Red Cards", "Yellow Cards"], ascending=[False, True])
# Out:
#                    Team  Yellow Cards  Red Cards
# 11  Republic of Ireland             6          1
# 9                Poland             7          1
# 6                Greece             9          1
# 2               Denmark             4          0
# 5               Germany             4          0
# 3               England             5          0
# 8           Netherlands             5          0
# 15              Ukraine             5          0
# 4                France             6          0
# 12               Russia             6          0
# 1        Czech Republic             7          0
# 14               Sweden             7          0
# 0               Croatia             9          0
# 13                Spain            11          0
# 10             Portugal            12          0
# 7                 Italy            16          0

# %%
euro12.sort_values??
# Out:
# Signature:
# euro12.sort_values(
#     by,
#     axis: 'Axis' = 0,
#     ascending=True,
#     inplace: 'bool' = False,
#     kind: 'str' = 'quicksort',
#     na_position: 'str' = 'last',
#     ignore_index: 'bool' = False,
#     key: 'ValueKeyFunc' = None,
# )
# Docstring:
# Sort by the values along either axis.
#
# Parameters
# ----------
#         by : str or list of str
#             Name or list of names to sort by.
#
#             - if `axis` is 0 or `'index'` then `by` may contain index
#               levels and/or column labels.
#             - if `axis` is 1 or `'columns'` then `by` may contain column
#               levels and/or index labels.
# axis : {0 or 'index', 1 or 'columns'}, default 0
#      Axis to be sorted.
# ascending : bool or list of bool, default True
#      Sort ascending vs. descending. Specify list for multiple sort
#      orders.  If this is a list of bools, must match the length of
#      the by.
# inplace : bool, default False
# ...

# %% [markdown]
# ### Step 9. Calculate the mean Yellow Cards given per Team

# %%
euro12["Yellow Cards"].mean()
# Out:
# 7.4375

# %% [markdown]
# ### Step 10. Filter teams that scored more than 6 goals

# %%
euro12.loc[euro12["Goals"]>6,["Team":"Goals"]]
# Out:
#        Team  Goals
# 5   Germany     10
# 13    Spain     12

# %% [markdown]
# ### Step 11. Select the teams that start with G

# %%
# Hay dos formas prácticas de hacerlo

# %%
euro12.loc[euro12["Team"].str.startswith("G"),["Team"]]
# Out:
#       Team
# 5  Germany
# 6   Greece

# %%
euro12.loc[euro12["Team"].str[0]=="G", ["Team", "Shooting Accuracy"]]
# Out:
#       Team Shooting Accuracy
# 5  Germany             47.8%
# 6   Greece             30.7%

# %% [markdown]
# ### Step 12. Select the first 7 columns

# %%
euro12.T.head(7).T
# Out:
#                    Team Goals Shots on target Shots off target  \
# 0               Croatia     4              13               12
# 1        Czech Republic     4              13               18
# 2               Denmark     4              10               10
# 3               England     5              11               18
# 4                France     3              22               24
# 5               Germany    10              32               32
# 6                Greece     5               8               18
# 7                 Italy     6              34               45
# 8           Netherlands     2              12               36
# 9                Poland     2              15               23
# 10             Portugal     6              22               42
# 11  Republic of Ireland     1               7               12
# 12               Russia     5               9               31
# 13                Spain    12              42               33
# ...

# %% [markdown]
# ### Step 13. Select all columns except the last 3.

# %%
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# ### Step 14. Present only the Shooting Accuracy from England, Italy and Russia

# %%
euro12.loc[euro12.Team.isin(["England", "Italy", "Russia"]),:]
# Out:
#        Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 3   England      5               11                18             50.0%
# 7     Italy      6               34                45             43.0%
# 12   Russia      5                9                31             22.5%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 3             17.2%                          40             0              0
# 7              7.5%                         110             2              0
# 12            12.5%                          59             2              0
#
#     Penalties not scored  Headed goals  Passes  Passes completed  \
# 3                      0             3    1488              1200
# 7                      0             2    3016              2531
# 12                     0             1    1602              1345
#
#    Passing Accuracy  Touches  Crosses  Dribbles  Corners Taken  Tackles  \
# ...

# %%
# Out:
#         Shooting Accuracy
# Team
# England             50.0%
# Italy               43.0%
# Russia              22.5%
